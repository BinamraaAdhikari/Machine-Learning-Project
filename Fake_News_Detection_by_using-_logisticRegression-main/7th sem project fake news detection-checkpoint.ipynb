# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
import numpy as np

# %%
true = pd.read_csv('data/True.csv')
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake = pd.read_csv('Data/Fake.csv')
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label'] = 1

# %%
fake['label'] = 0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news =pd.concat([fake, true], axis = 0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
true.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
#  4   label    21417 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 836.7+ KB

# %%
true.shape
# Out:
# (21417, 5)

# %%
fake.shape
# Out:
# (23481, 5)

# %%
23481+21417
# Out:
# 44898

# %%
news.shape
# Out:
# (44898, 5)

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title', 'subject', 'date'], axis = 1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac = 1) # reshuffling

# %%
news.head()
# Out:
#                                                     text  label
# 2877   (Reuters) - The state of Hawaii renewed its bi...      1
# 16498  Lawless, Crooked Hillary promises to continue ...      0
# 21493  Are these faux blacks cashing in on victim sta...      0
# 12082  QUETTA, Pakistan/ISLAMABAD (Reuters) - Two sui...      1
# 3514   Democrats and other progressives who watched h...      0

# %%
news.reset_index(inplace = True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   2877  (Reuters) - The state of Hawaii renewed its bi...      1
# 1  16498  Lawless, Crooked Hillary promises to continue ...      0
# 2  21493  Are these faux blacks cashing in on victim sta...      0
# 3  12082  QUETTA, Pakistan/ISLAMABAD (Reuters) - Two sui...      1
# 4   3514  Democrats and other progressives who watched h...      0

# %%
news.drop(['index'], axis = 1, inplace = True)
news.head()
# Out:
#                                                 text  label
# 0  (Reuters) - The state of Hawaii renewed its bi...      1
# 1  Lawless, Crooked Hillary promises to continue ...      0
# 2  Are these faux blacks cashing in on victim sta...      0
# 3  QUETTA, Pakistan/ISLAMABAD (Reuters) - Two sui...      1
# 4  Democrats and other progressives who watched h...      0

# %%
def wordopt(text):
    # convert into lowercase
    text = text.lower()  

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+','',text)

    # Remove HTML tags
    text = re.sub(r'<.*?>','',text)

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Remove digits
    text = re.sub(r'\d', ' ', text)

    # Remove newline characters
    text  = re.sub(r'\n', ' ', text)

    return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        reuters  the state of hawaii renewed its bid t...
# 1        lawless crooked hillary promises to continue w...
# 2        are these faux blacks cashing in on victim sta...
# 3        quetta pakistanislamabad reuters  two suicide ...
# 4        democrats and other progressives who watched h...
#                                ...
# 44893    these videos will shock you when you think of ...
# 44894    washington reuters  us president donald trump ...
# 44895    with absolutely no shame or apology republican...
# 44896    washington reuters  bernie sanders promised on...
# 44897    lee young owner of hitman firearms posted this...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        reuters  the state of hawaii renewed its bid t...
# 1        lawless crooked hillary promises to continue w...
# 2        are these faux blacks cashing in on victim sta...
# 3        quetta pakistanislamabad reuters  two suicide ...
# 4        democrats and other progressives who watched h...
#                                ...
# 44893    these videos will shock you when you think of ...
# 44894    washington reuters  us president donald trump ...
# 44895    with absolutely no shame or apology republican...
# 44896    washington reuters  bernie sanders promised on...
# 44897    lee young owner of hitman firearms posted this...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 44893    0
# 44894    1
# 44895    0
# 44896    1
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %% [markdown]
# #### implement Logistic regression mannually

# %%
from scipy.sparse import csr_matrix

# Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Sparse Logistic Regression
class LogisticRegressionSparse:
    def __init__(self, lr=0.1, epochs=100):
        self.lr = lr
        self.epochs = epochs
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        m, n = X.shape
        self.weights = np.zeros(n)
        self.bias = 0

        for _ in range(self.epochs):
            # Sparse matrix multiplication
            z = X.dot(self.weights) + self.bias
            y_pred = sigmoid(z)

            # Gradient calculation
            error = y_pred - y
            dw = (X.T.dot(error)) / m   # works with sparse
            db = np.sum(error) / m

            # Update weights and bias
            self.weights -= self.lr * dw
            self.bias -= self.lr * db

    def predict_proba(self, X):
        z = X.dot(self.weights) + self.bias
        return sigmoid(z)

    def predict(self, X):
        y_pred = self.predict_proba(X)
        return np.where(y_pred > 0.5, 1, 0)

# %% [markdown]
# # test for 70-30

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.3, random_state = 15)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
vectorization = TfidfVectorizer(max_features=20000, ngram_range=(1,2), sublinear_tf=True)

# %%
import joblib

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
joblib.dump(vectorization, 'vectorization.pkl')
# Out:
# ['vectorization.pkl']

# %%
model = LogisticRegressionSparse(lr=0.1, epochs=10000)
model.fit(xv_train, y_train)

# Predictions
y_pred_train = model.predict(xv_train)
y_pred_test = model.predict(xv_test)

# Accuracy
accuracy = lambda y_true, y_pred: np.mean(y_true == y_pred)
print("Train Accuracy:", accuracy(y_train, y_pred_train))
print("Test Accuracy:", accuracy(y_test, y_pred_test))
# Out:
# Train Accuracy: 0.9693903525518646
# Test Accuracy: 0.9708240534521159

# %%
cm3 = confusion_matrix(y_test, y_pred_test)
print(cm3)
# Generate confusion matrix
class_names = ['Real', 'Fake']  # Change as per your class labels

plt.figure(figsize=(8,6))
sns.heatmap(cm3, annot=True, fmt='g', cmap='Blues', linewidths=1, linecolor='black', 
            xticklabels=class_names, yticklabels=class_names, cbar=True)

plt.title('Confusion Matrix for Fake News Detection', fontsize=16)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# Out:
# [[6837  218]
#  [ 175 6240]]

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      7055
#            1       0.97      0.97      0.97      6415
#
#     accuracy                           0.97     13470
#    macro avg       0.97      0.97      0.97     13470
# weighted avg       0.97      0.97      0.97     13470

# %% [markdown]
# ### test for 50 -50

# %%
x5_train, x5_test, y5_train, y5_test = train_test_split(x, y,test_size = 0.5, random_state = 15)

# %%
vectorization5 = TfidfVectorizer(max_features=10000)

# %%
xv_train5 = vectorization5.fit_transform(x5_train)

# %%
xv_test5 = vectorization5.transform(x5_test)

# %%
model5 = LogisticRegressionSparse(lr=0.1, epochs=1000)
model5.fit(xv_train5, y5_train)

y_pred_train5 = model5.predict(xv_train5)
y_pred_test5 = model5.predict(xv_test5)

# Accuracy
accuracy = lambda y_true, y_pred: np.mean(y_true == y_pred)
print("Train Accuracy:", accuracy(y5_train, y_pred_train5))
print("Test Accuracy:", accuracy(y5_test, y_pred_test5))
# Out:
# Train Accuracy: 0.9379482382288743
# Test Accuracy: 0.9388836919239164

# %%
cm5 = confusion_matrix(y5_test, y_pred_test5)
print(cm5)
# Generate confusion matrix
class_names = ['Real', 'Fake']  # Change as per your class labels

plt.figure(figsize=(8,6))
sns.heatmap(cm5, annot=True, fmt='g', cmap='Blues', linewidths=1, linecolor='black', 
            xticklabels=class_names, yticklabels=class_names, cbar=True)

plt.title('Confusion Matrix for Fake News Detection', fontsize=16)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# Out:
# [[11308   426]
#  [  946  9769]]

# %%
print(classification_report(y5_test, y_pred_test5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     11734
#            1       0.96      0.91      0.93     10715
#
#     accuracy                           0.94     22449
#    macro avg       0.94      0.94      0.94     22449
# weighted avg       0.94      0.94      0.94     22449

# %% [markdown]
# ## Test for 60-40

# %%
x4_train, x4_test, y4_train, y4_test = train_test_split(x, y,test_size = 0.4, random_state = 15)

# %%
vectorization4 = TfidfVectorizer(max_features=10000)

# %%
xv_train4 = vectorization4.fit_transform(x4_train)

# %%
xv_test4 = vectorization4.transform(x4_test)

# %%
model4 = LogisticRegressionSparse(lr=0.1, epochs=1000)
model4.fit(xv_train4, y4_train)

y_pred_train4 = model.predict(xv_train4)
y_pred_test4 = model.predict(xv_test4)

# Accuracy
accuracy = lambda y_true, y_pred: np.mean(y_true == y_pred)
print("Train Accuracy:", accuracy(y4_train, y_pred_train4))
print("Test Accuracy:", accuracy(y4_test, y_pred_test4))
# Out:
# Train Accuracy: 0.5909867102234762
# Test Accuracy: 0.5887527839643653

# %%
cm4 = confusion_matrix(y4_test, y_pred_test4)
print(cm4)
# Generate confusion matrix
class_names = ['Real', 'Fake']  # Change as per your class labels

plt.figure(figsize=(8,6))
sns.heatmap(cm4, annot=True, fmt='g', cmap='Blues', linewidths=1, linecolor='black', 
            xticklabels=class_names, yticklabels=class_names, cbar=True)

plt.title('Confusion Matrix for Fake News Detection', fontsize=16)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# Out:
# [[9300   88]
#  [7298 1274]]

# %%
print(classification_report(y4_test, y_pred_test4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.99      0.72      9388
#            1       0.94      0.15      0.26      8572
#
#     accuracy                           0.59     17960
#    macro avg       0.75      0.57      0.49     17960
# weighted avg       0.74      0.59      0.50     17960

# %% [markdown]
# # test for 80-20

# %%
x2_train, x2_test, y2_train, y2_test = train_test_split(x, y,test_size = 0.2, random_state = 15)

# %%
vectorization2 = TfidfVectorizer(max_features=10000)

# %%
xv_train2 = vectorization2.fit_transform(x2_train)

# %%
xv_test2 = vectorization2.transform(x2_test)

# %%
model2 = LogisticRegressionSparse(lr=0.1, epochs=1000)
model2.fit(xv_train2, y2_train)

y_pred_train2 = model.predict(xv_train2)
y_pred_test2 = model.predict(xv_test2)

# Accuracy
accuracy = lambda y_true, y_pred: np.mean(y_true == y_pred)
print("Train Accuracy:", accuracy(y2_train, y_pred_train2))
print("Test Accuracy:", accuracy(y2_test, y_pred_test2))
# Out:
# Train Accuracy: 0.5282309705440169
# Test Accuracy: 0.5241648106904232

# %%
cm2 = confusion_matrix(y2_test, y_pred_test2)
print(cm2)
# Generate confusion matrix
class_names = ['Real', 'Fake']  # Change as per your class labels

plt.figure(figsize=(8,6))
sns.heatmap(cm2, annot=True, fmt='g', cmap='Blues', linewidths=1, linecolor='black', 
            xticklabels=class_names, yticklabels=class_names, cbar=True)

plt.title('Confusion Matrix for Fake News Detection', fontsize=16)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# Out:
# [[4660   15]
#  [4258   47]]

# %%
print(classification_report(y2_test, y_pred_test2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.69      4675
#            1       0.76      0.01      0.02      4305
#
#     accuracy                           0.52      8980
#    macro avg       0.64      0.50      0.35      8980
# weighted avg       0.64      0.52      0.37      8980

# %% [markdown]
# ### logistic regression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# 1. joblib.dump - save
# 2. joblib.load

# %%
joblib.dump(model, 'LR_model.pkl')
# Out:
# ['LR_model.pkl']

# %%
newsmodel = joblib.load('LR_model.pkl')

# %%
sample_text = ['JAKARTA (Reuters) - Indonesia will buy 11 Sukhoi fighter jets worth $1.14 billion from Russia in exchange for cash and Indonesian commodities, two cabinet ministers said on Tuesday. The Southeast Asian country has pledged to ship up to $570 million worth of commodities in addition to cash to pay for the Suhkoi SU-35 fighter jets, which are expected to be delivered in stages starting in two years. Indonesian Trade Minister Enggartiasto Lukita said in a joint statement with Defence Minister Ryamizard Ryacudu that details of the type and volume of commodities were  still being negotiated . Previously he had said the exports could include palm oil, tea, and coffee. The deal is expected to be finalised soon between Indonesian state trading company PT Perusahaan Perdangangan Indonesia and Russian state conglomerate Rostec. Russia is currently facing a new round of U.S.-imposed trade sanctions. Meanwhile, Southeast Asia s largest economy is trying to promote its palm oil products amid threats of a cut in consumption by European Union countries. Indonesia is also trying to modernize its ageing air force after a string of military aviation accidents. Indonesia, which had a $411 million trade surplus with Russia in 2016, wants to expand bilateral cooperation in tourism, education, energy, technology and aviation among others. ']

# Step 1: Convert text to vector
sample_text_vector = vectorization.transform(sample_text)

# Step 2: Predict
print(newsmodel.predict(sample_text_vector))
# Out:
# [1]

# %%
def output_label(n):
    if n== 0:
        return "It is a Fake News."
    elif n== 1:
        return "It is a Genuine News."

# %%
def manual_testing(news):
    testing_news = {"text": [news]}  # Create DataFrame from input text
    new_def_test = pd.DataFrame(testing_news)
    
    # Text preprocessing (assuming you have a wordopt() function for cleaning)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    
    # Vectorization (Assuming 'vectorization' is your trained TfidfVectorizer)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    
    # Prediction using Logistic Regression
    pred_lr = newsmodel.predict(new_xv_test)

    return "\n\nLR Prediction: {}".format(output_label(pred_lr[0]))

# %%
news_artical = input()
# Out:
#  BUENOS AIRES (Reuters) - Argentina s main labor unions took to the streets of the capital on Tuesday demanding more jobs and protesting center-right President Mauricio Macri s economic policies.  Tens of thousands of workers gathered in the historic Plaza de Mayo criticizing Macri, who is trying to lower labor costs to attract investment and jump-start an economy that emerged from recession in the second half of last year.  If some retrograde (in the government) thinks that lowering wages, precarious living conditions and destroying trade unions is going to line up investments... we say that is very wrong,  said Juan Carlos Schmid, a leader of Argentina s largest umbrella union, the CGT. Standing on a podium at the protest, he said the CGT would meet in late September to discuss a potential strike.  Macri told Reuters in an interview this month his government was negotiating labor agreements sector by sector rather than trying to pass a comprehensive labor reform like the one approv
# ...

# %%
manual_testing(news_artical)
# Out:
# '\n\nLR Prediction: It is a Genuine News.'
